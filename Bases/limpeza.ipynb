# %%
import pandas as pd

# %%
dt = pd.read_excel('7 - ComercialPrime_300_Registros.xlsx')

# %%
dt
# Out:
#      ID_Registro Data_Pedido Numero_Pedido              Cliente  \
# 0              1  2025-02-28      PED-1001       Construtora PR
# 1              2  2025-01-30      PED-1002         Cliente XPTO
# 2              3  2025-05-09      PED-1003         Cliente XPTO
# 3              4  2025-05-21      PED-1004       Construtora PR
# 4              5  2025-03-23      PED-1005       Construtora PR
# ..           ...         ...           ...                  ...
# 295          296  2025-03-29      PED-1296  Loja Ferramentas BR
# 296          297  2025-03-13      PED-1297       Construtora PR
# 297          298  2025-05-11      PED-1298     Oficina Curitiba
# 298          299  2025-03-17      PED-1299   Mercado Industrial
# 299          300  2025-03-09      PED-1300         Cliente XPTO
#
#     Cidade_Cliente Estado   Vendedor        Produto    Categoria  Quantidade  \
# 0         Cascavel     PR  Carlos S.      Soldadora      Medição           9
# ...

# %%
sorted(dt['Cidade_Cliente'].unique())
# Out:
# ['Araucária', 'Cascavel', 'Curitiba', 'Londrina', 'Maringá', 'Ponta Grossa']

# %%
sorted(dt['Comentario_Satisfacao'].unique())
# Out:
# ['Muito Insatisfeito', 'Muito Satisfeito', 'Neutro']

# %%
dt['Produto'].unique()
# Out:
# <StringArray>
# ['Soldadora', 'Parafusadeira', 'Furadeira']
# Length: 3, dtype: str

# %%
media = dt.loc[dt["Produto"] == "Parafusadeira", "Valor_Unitario"].mean()
media
# Out:
# np.float64(2456.845684210526)

# %%
dt.loc[dt["Produto"] == "Parafusadeira", "Valor_Unitario"] = media

# %%
dt.loc[dt["Produto"] == "Parafusadeira"]
# Out:
#      ID_Registro Data_Pedido Numero_Pedido             Cliente Cidade_Cliente  \
# 1              2  2025-01-30      PED-1002        Cliente XPTO        Maringá
# 3              4  2025-05-21      PED-1004      Construtora PR   Ponta Grossa
# 4              5  2025-03-23      PED-1005      Construtora PR        Maringá
# 5              6  2025-06-28      PED-1006      Construtora PR       Cascavel
# 7              8  2025-03-13      PED-1008      Construtora PR       Londrina
# ..           ...         ...           ...                 ...            ...
# 292          293  2025-01-24      PED-1293     Indústria Alpha       Cascavel
# 294          295  2025-03-22      PED-1295     Metalúrgica Sul      Araucária
# 297          298  2025-05-11      PED-1298    Oficina Curitiba        Maringá
# 298          299  2025-03-17      PED-1299  Mercado Industrial       Curitiba
# 299          300  2025-03-09      PED-1300        Cliente XPTO   Ponta Grossa
#
# ...

# %%
dt["Valor_Total"] = dt["Quantidade"] * dt["Valor_Unitario"]

# %%
dt.loc[dt["Produto"] == "Parafusadeira"]
# Out:
#      ID_Registro Data_Pedido Numero_Pedido             Cliente Cidade_Cliente  \
# 1              2  2025-01-30      PED-1002        Cliente XPTO        Maringá
# 3              4  2025-05-21      PED-1004      Construtora PR   Ponta Grossa
# 4              5  2025-03-23      PED-1005      Construtora PR        Maringá
# 5              6  2025-06-28      PED-1006      Construtora PR       Cascavel
# 7              8  2025-03-13      PED-1008      Construtora PR       Londrina
# ..           ...         ...           ...                 ...            ...
# 292          293  2025-01-24      PED-1293     Indústria Alpha       Cascavel
# 294          295  2025-03-22      PED-1295     Metalúrgica Sul      Araucária
# 297          298  2025-05-11      PED-1298    Oficina Curitiba        Maringá
# 298          299  2025-03-17      PED-1299  Mercado Industrial       Curitiba
# 299          300  2025-03-09      PED-1300        Cliente XPTO   Ponta Grossa
#
# ...

# %%
dt.Categoria.unique()
# Out:
# <StringArray>
# ['Medição', 'Ferramentas', 'Soldagem', 'Elétrica']
# Length: 4, dtype: str

# %%
dt.loc[dt["Produto"] == "Parafusadeira", "Categoria"] = "Ferramentas"

# %%
dt.Produto.unique()
# Out:
# <StringArray>
# ['Soldadora', 'Parafusadeira', 'Furadeira']
# Length: 3, dtype: str

# %%
dt.loc[dt["Produto"] == "Soldadora"]
# Out:
#      ID_Registro Data_Pedido Numero_Pedido           Cliente Cidade_Cliente  \
# 0              1  2025-02-28      PED-1001    Construtora PR       Cascavel
# 2              3  2025-05-09      PED-1003      Cliente XPTO      Araucária
# 8              9  2025-02-12      PED-1009      Cliente XPTO      Araucária
# 16            17  2025-03-25      PED-1017    Construtora PR   Ponta Grossa
# 18            19  2025-02-21      PED-1019    Construtora PR       Curitiba
# ..           ...         ...           ...               ...            ...
# 274          275  2025-02-24      PED-1275  Oficina Curitiba        Maringá
# 281          282  2025-02-17      PED-1282  Oficina Curitiba      Araucária
# 287          288  2025-02-09      PED-1288      Cliente XPTO        Maringá
# 289          290  2025-01-01      PED-1290   Metalúrgica Sul       Curitiba
# 296          297  2025-03-13      PED-1297    Construtora PR       Cascavel
#
# ...

# %%
mediaS = dt.loc[dt["Produto"] == "Soldadora", "Valor_Unitario"].mean()
mediaS
# Out:
# np.float64(2570.3376344086023)

# %%
dt.loc[dt["Produto"] == "Soldadora", "Valor_Unitario"] = mediaS

# %%
dt.loc[dt["Produto"] == "Soldadora"]
# Out:
#      ID_Registro Data_Pedido Numero_Pedido           Cliente Cidade_Cliente  \
# 0              1  2025-02-28      PED-1001    Construtora PR       Cascavel
# 2              3  2025-05-09      PED-1003      Cliente XPTO      Araucária
# 8              9  2025-02-12      PED-1009      Cliente XPTO      Araucária
# 16            17  2025-03-25      PED-1017    Construtora PR   Ponta Grossa
# 18            19  2025-02-21      PED-1019    Construtora PR       Curitiba
# ..           ...         ...           ...               ...            ...
# 274          275  2025-02-24      PED-1275  Oficina Curitiba        Maringá
# 281          282  2025-02-17      PED-1282  Oficina Curitiba      Araucária
# 287          288  2025-02-09      PED-1288      Cliente XPTO        Maringá
# 289          290  2025-01-01      PED-1290   Metalúrgica Sul       Curitiba
# 296          297  2025-03-13      PED-1297    Construtora PR       Cascavel
#
# ...

# %%
dt.loc[dt["Produto"] == "Soldadora", "Categoria"] = "Ferramentas"

# %%
dt.Produto.unique()
# Out:
# <StringArray>
# ['Soldadora', 'Parafusadeira', 'Furadeira']
# Length: 3, dtype: str

# %%
dt.loc[dt["Produto"] == "Furadeira"]
# Out:
#      ID_Registro Data_Pedido Numero_Pedido              Cliente  \
# 6              7  2025-05-19      PED-1007         Cliente XPTO
# 10            11  2025-01-16      PED-1011         Cliente XPTO
# 12            13  2025-03-11      PED-1013       Construtora PR
# 19            20  2025-01-30      PED-1020       Construtora PR
# 23            24  2025-01-17      PED-1024         Cliente XPTO
# ..           ...         ...           ...                  ...
# 285          286  2025-01-02      PED-1286      Indústria Alpha
# 286          287  2025-05-15      PED-1287      Indústria Alpha
# 288          289  2025-06-30      PED-1289   Mercado Industrial
# 293          294  2025-05-27      PED-1294      Metalúrgica Sul
# 295          296  2025-03-29      PED-1296  Loja Ferramentas BR
#
#     Cidade_Cliente Estado   Vendedor    Produto    Categoria  Quantidade  \
# 6          Maringá     PR  Carlos S.  Furadeira      Medição          29
# ...

# %%
mediaF = dt.loc[dt["Produto"] == "Furadeira", "Valor_Unitario"].mean()
mediaF
# Out:
# np.float64(2619.245535714286)

# %%
dt.loc[dt["Produto"] == "Furadeira", "Valor_Unitario"] = mediaF

# %%
dt.loc[dt["Produto"] == "Furadeira", "Categoria"] = "Ferramentas"

# %%
dt.loc[dt["Produto"] == "Furadeira"]
# Out:
#      ID_Registro Data_Pedido Numero_Pedido              Cliente  \
# 6              7  2025-05-19      PED-1007         Cliente XPTO
# 10            11  2025-01-16      PED-1011         Cliente XPTO
# 12            13  2025-03-11      PED-1013       Construtora PR
# 19            20  2025-01-30      PED-1020       Construtora PR
# 23            24  2025-01-17      PED-1024         Cliente XPTO
# ..           ...         ...           ...                  ...
# 285          286  2025-01-02      PED-1286      Indústria Alpha
# 286          287  2025-05-15      PED-1287      Indústria Alpha
# 288          289  2025-06-30      PED-1289   Mercado Industrial
# 293          294  2025-05-27      PED-1294      Metalúrgica Sul
# 295          296  2025-03-29      PED-1296  Loja Ferramentas BR
#
#     Cidade_Cliente Estado   Vendedor    Produto    Categoria  Quantidade  \
# 6          Maringá     PR  Carlos S.  Furadeira  Ferramentas          29
# ...

# %%
print(f"{mediaF:.2f}")
# Out:
# 2619.25

# %%
dt
# Out:
#      ID_Registro Data_Pedido Numero_Pedido              Cliente  \
# 0              1  2025-02-28      PED-1001       Construtora PR
# 1              2  2025-01-30      PED-1002         Cliente XPTO
# 2              3  2025-05-09      PED-1003         Cliente XPTO
# 3              4  2025-05-21      PED-1004       Construtora PR
# 4              5  2025-03-23      PED-1005       Construtora PR
# ..           ...         ...           ...                  ...
# 295          296  2025-03-29      PED-1296  Loja Ferramentas BR
# 296          297  2025-03-13      PED-1297       Construtora PR
# 297          298  2025-05-11      PED-1298     Oficina Curitiba
# 298          299  2025-03-17      PED-1299   Mercado Industrial
# 299          300  2025-03-09      PED-1300         Cliente XPTO
#
#     Cidade_Cliente Estado   Vendedor        Produto    Categoria  Quantidade  \
# 0         Cascavel     PR  Carlos S.      Soldadora  Ferramentas           9
# ...

# %%
dt = dt.drop("Comentario_Satisfacao", axis=1)

# %%
dt
# Out:
#      ID_Registro Data_Pedido Numero_Pedido              Cliente  \
# 0              1  2025-02-28      PED-1001       Construtora PR
# 1              2  2025-01-30      PED-1002         Cliente XPTO
# 2              3  2025-05-09      PED-1003         Cliente XPTO
# 3              4  2025-05-21      PED-1004       Construtora PR
# 4              5  2025-03-23      PED-1005       Construtora PR
# ..           ...         ...           ...                  ...
# 295          296  2025-03-29      PED-1296  Loja Ferramentas BR
# 296          297  2025-03-13      PED-1297       Construtora PR
# 297          298  2025-05-11      PED-1298     Oficina Curitiba
# 298          299  2025-03-17      PED-1299   Mercado Industrial
# 299          300  2025-03-09      PED-1300         Cliente XPTO
#
#     Cidade_Cliente Estado   Vendedor        Produto    Categoria  Quantidade  \
# 0         Cascavel     PR  Carlos S.      Soldadora  Ferramentas           9
# ...

# %%
dt.to_excel("Dados_ComercialPrime_Tratado.xlsx", index=False)
